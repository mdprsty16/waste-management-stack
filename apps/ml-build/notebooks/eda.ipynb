# %% [markdown]
# # 1. Data Loading & Chronological Inspection

# %% [markdown]
# ## 1.1. Import Libraries & Configurations

# %% [markdown]
# ## 1.2. Loading & Parsing Datetime

# %% [markdown]
# ## 1.3. Setting Index & Checking Chronology

# %% [markdown]
# # 2. Data Cleaning & Handling Gaps
